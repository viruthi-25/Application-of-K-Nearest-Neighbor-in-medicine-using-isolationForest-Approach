# %%
     from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
avdiatem=avmra

# %%
avdia1=[0.3,0.2,0.0,0.0,0.0]
avmra1=[0.3,0.2,0.0,0.0,0.0]

# %%
a=pd.read_csv('Breastcancer.csv')
a1=pd.read_csv('Image_seg.csv')
a2=pd.read_csv('Parkinsons.csv')

# %%
a.head(20)
# Out:
#     1000025   5   1  1.1  1.2  2  1.3  3  1.4  1.5  2.1
# 0   1002945   5   4    4    5  7   10  3    2    1    2
# 1   1015425   3   1    1    1  2    2  3    1    1    2
# 2   1016277   6   8    8    1  3    4  3    7    1    2
# 3   1017023   4   1    1    3  2    1  3    1    1    2
# 4   1017122   8  10   10    8  7   10  9    7    1    4
# 5   1018099   1   1    1    1  2   10  3    1    1    2
# 6   1018561   2   1    2    1  2    1  3    1    1    2
# 7   1033078   2   1    1    1  2    1  1    1    5    2
# 8   1033078   4   2    1    1  2    1  2    1    1    2
# 9   1035283   1   1    1    1  1    1  3    1    1    2
# 10  1036172   2   1    1    1  2    1  2    1    1    2
# 11  1041801   5   3    3    3  2    3  4    4    1    4
# 12  1043999   1   1    1    1  2    3  3    1    1    2
# 13  1044572   8   7    5   10  7    9  5    5    4    4
# 14  1047630   7   4    6    4  6    1  4    3    1    4
# 15  1048672   4   1    1    1  2    1  2    1    1    2
# 16  1049815   4   1    1    1  2    1  3    1    1    2
# 17  1050670  10   7    7    6  4   10  4    1    2    4
# 18  1050718   6   1    1    1  2    1  3    1    1    2
# 19  1054590   7   3    2   10  5   10  5    4    4    4

# %%
a1.head(20)
# Out:
#    REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0                GRASS                110.0               189.0
# 1                GRASS                 86.0               187.0
# 2                GRASS                225.0               244.0
# 3                GRASS                 47.0               232.0
# 4                GRASS                 97.0               186.0
# 5                GRASS                157.0               221.0
# 6                GRASS                 62.0               224.0
# 7                GRASS                 27.0               248.0
# 8                GRASS                 44.0               233.0
# 9                GRASS                 17.0               229.0
# 10               GRASS                 32.0               240.0
# 11               GRASS                 55.0               209.0
# 12               GRASS                138.0               203.0
# 13               GRASS                 90.0               189.0
# 14               GRASS                245.0               238.0
# 15               GRASS                 58.0               217.0
# 16               GRASS                146.0               201.0
# 17               GRASS                 19.0               184.0
# 18               GRASS                245.0               176.0
# 19               GRASS                228.0               182.0
#
#     SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0                    9.0              0.000000         0.0  1.000000
# 1                    9.0              0.000000         0.0  1.111111
# 2                    9.0              0.000000         0.0  3.388889
# 3                    9.0              0.000000         0.0  1.277778
# 4                    9.0              0.000000         0.0  1.166667
# 5                    9.0              0.000000         0.0  1.055556
# 6                    9.0              0.000000         0.0  0.944445
# 7                    9.0              0.111111         0.0  1.611111
# 8                    9.0              0.000000         0.0  2.222222
# 9                    9.0              0.000000         0.0  2.111111
# 10                   9.0              0.000000         0.0  1.277778
# 11                   9.0              0.111111         0.0  1.833333
# 8    38  113  186  456   86  261  129   0   82   62  ...    176    309     75
# 9     0    0  102  111    0  553  400   0   34    0  ...    254    610     33
# 10   17   26    0  299    0  501    0   0   17  144  ...    207    409      0
# 11    0   81   42  179   34  492  447   0   14    0  ...    166    607     70
# 12  106    6  116  438    0  246  410   0    0    0  ...    863      2     29
# 13    7    6    0  199    0  440    0   0   39  363  ...    590    566     88
# 14   71   34  184  341    0  296  266   0    0    0  ...    771      0     63
# 15   13   58   17  488   38  339  177   0   30  125  ...     80    314      0
# 16    0    0    0  543   64  453    0   0  150  177  ...    255    446     75
# 17  132    0  171  394    0  247  129   0    0    0  ...    854      0     46
# 18    3   46    0  426    0  533    0  16  113  165  ...    236    490      0
# 19   29   21    0  366   50  531    0   0  146  152  ...    240    522     96
#
#     0.5762  36.31  0.5763  80.18  0.5764  0.5765  524
# 0        7    473       0     57       0     284  423
# 1        0     24       0     90       0      34  508
# 2       26     86       0    102       0       0  469
# 3        0      0     190    301       0       0  354
# 4       36      2     369    194      18      59  340
# 5        0      0     247    401       0      17  412
# 6        0      0     258    422       0     167  409
# 7        0     23       0     97       0      47  520
# 8       61     63     169    227       0      10  179
# 9        0    383       0     72       0      69  431
# 10      33      0     323    238       0       0  331
# 11      31    104       0    146       0     304  422
# 12       0      0     237    285       0       0  301
# 13       0     71     409    207       0      39  254
# 14       0      0     271    402       0       0  342
# 15      67     57     137    290       0     392  238
# 16      60    183     299    146       0       0  270
# 17       0      0     173    372       0     344  353
# 18      13    139     313     55       0      35  227
# 19      47     38     362     88       0       0  219
#
# [20 rows x 10000 columns]

# %%
b=pd.read_csv('musk.csv')
b.head(20)
# Out:
#     MUSK-188  188_1+1  42  -198  -109  -75  -117   11  23  -88  ...  -74  \
# 0   MUSK-188  188_1+2  42  -191  -142  -65  -117   55  49 -170  ... -302
# 1   MUSK-188  188_1+3  42  -191  -142  -75  -117   11  49 -161  ...  -73
# 2   MUSK-188  188_1+4  42  -198  -110  -65  -117   55  23  -95  ... -302
# 3   MUSK-190  190_1+1  42  -198  -102  -75  -117   10  24  -87  ...  -73
# 4   MUSK-190  190_1+2  42  -191  -142  -65  -117   55  49 -170  ... -300
# 5   MUSK-190  190_1+3  42  -190  -142  -75  -117   12  49 -161  ...  -72
# 6   MUSK-190  190_1+4  42  -199  -102  -65  -117   55  23  -94  ... -300
# 7   MUSK-211  211_1+1  40  -173  -142   13  -116   -7  50 -171  ...  -53
# 8   MUSK-211  211_1+2  44  -159   -63  -74  -117   17   5 -114  ...  -62
# 9   MUSK-212  212_1+1  42  -170   -63  -65  -117   58  11 -136  ... -298
# 10  MUSK-212  212_1+2  41   -95   -61  -75  -117   15  30 -164  ...  -78
# 11  MUSK-212  212_1+3  45  -199  -108   13  -117   -6  24  -96  ...  -50
# 12  MUSK-213  213_1+1  41    90  -141   12  -116   -8  49 -169  ...  -55
# 13  MUSK-213  213_1+2  70   -30   -61  -73  -117   11  12 -118  ...  -76
# 14  MUSK-213  213_1+3  85  -158   -63  -74  -117   18   5 -114  ...  -63
aN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN
# 8       -1.4943      -1.4943      -1.4943          1.0
# 9           NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN
#
# [20 rows x 49 columns]

# %%
b=pd.read_csv('smart.csv')
b.head(20)
# Out:
#     2.89E-01  -2.03E-02  -1.33E-01  -9.95E-01  -9.83E-01  -9.14E-01  \
# 0      0.278   -0.01640    -0.1240     -0.998     -0.975     -0.960
# 1      0.280   -0.01950    -0.1130     -0.995     -0.967     -0.979
# 2      0.279   -0.02620    -0.1230     -0.996     -0.983     -0.991
# 3      0.277   -0.01660    -0.1150     -0.998     -0.981     -0.990
# 4      0.277   -0.01010    -0.1050     -0.997     -0.990     -0.995
# 5      0.279   -0.01960    -0.1100     -0.997     -0.967     -0.983
# 6      0.277   -0.03050    -0.1250     -0.997     -0.967     -0.982
# 7      0.277   -0.02180    -0.1210     -0.997     -0.961     -0.984
# 8      0.281   -0.00996    -0.1060     -0.995     -0.973     -0.986
# 9      0.277   -0.01270    -0.1030     -0.995     -0.973     -0.985
# 10     0.276   -0.02140    -0.1080     -0.998     -0.987     -0.993
# 11     0.278   -0.02040    -0.1130     -0.999     -0.985     -0.996
# 12     0.277   -0.01470    -0.1070     -0.999     -0.991     -0.993
# 13     0.298    0.02710    -0.0617     -0.989     -0.817     -0.902
# 14     0.279   -0.02300    -0.1220     -0.997     -0.975     -0.983
# 15     0.279   -0.01480    -0.1170     -0.997     -0.982     -0.983
# 16     0.280   -0.01390    -0.1060     -0.998     -0.988     -0.990
# 17     0.278   -0.01820    -0.1090     -0.997     -0.993     -0.996
# 18     0.276   -0.01700    -0.1110     -0.998     -0.991     -0.998
# 19     0.278   -0.01430    -0.1080     -0.998     -0.994     -0.996
#
#     -9.95E-01.1  -9.83E-01.1  -9.24E-01  -9.35E-01  ...  -7.43E-02  -2.99E-01  \
# 0        -0.999       -0.975     -0.958     -0.943  ...     0.1580    -0.5950
# 1        -0.997       -0.964     -0.977     -0.939  ...     0.4150    -0.3910
# 2        -0.997       -0.983     -0.989     -0.939  ...     0.4050    -0.1170
# 3        -0.998       -0.980     -0.990     -0.942  ...     0.0878    -0.3510
# 4        -0.998       -0.990     -0.996     -0.942  ...     0.0200    -0.5450
# 5        -0.997       -0.966     -0.983     -0.941  ...     0.1460    -0.2170
# 6        -0.996       -0.966     -0.983     -0.941  ...     0.1360    -0.0823
# 7        -0.998       -0.957     -0.984     -0.941  ...     0.3140    -0.2690
# 8        -0.995       -0.974     -0.986     -0.940  ...     0.2670     0.3400

# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-4a13e677a4ed> in <module>
# ----> 1 b=pd.read_csv('slice_localization_data.csv')
#       2 b.head(20)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'slice_localization_data.csv'

# %%
pip install rpforest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rpforest
#   Downloading rpforest-1.6.tar.gz (4.4 MB)
#      |████████████████████████████████| 4.4 MB 4.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy<2.0.0,>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from rpforest) (1.21.6)
# Building wheels for collected packages: rpforest
#   Building wheel for rpforest (PEP 517) ... done
#   Created wheel for rpforest: filename=rpforest-1.6-cp38-cp38-linux_x86_64.whl size=742708 sha256=0eda2b654a93028466913ca40c08ae75f80c8ab7ab10938ecb3a4905e40fd081
#   Stored in directory: /root/.cache/pip/wheels/df/26/63/a77c18a38ff022d14957abb53e9327a9372157e6c04a775227
# Successfully built rpforest
# Installing collected packages: rpforest
# Successfully installed rpforest-1.6

# %%
import numpy
import threading
import csv
from rpforest import RPForest

# %%
import threading
import sys

# %%
def leaves(predict, leaf):
    treeleaves = predict[0:leaf]
    return treeleaves

# %%
def missrateav(n, k, model, data, labels, leaf):
    miss = 0
    for i in range(n):
        count = 0
        predict = model.get_candidates(data[i], number=k, normalise=False)
        treeleaves = leaves(predict, leaf)
        for j in range(leaf):
            if labels[treeleaves[j]] == labels[i]:
                count = count + 1
        if count < k:
            miss = miss + k - count
    return miss / (n*k)

# %%
def discrepancyav(n, k, model, data):
    dist = 0
    for i in range(n):
        predict = model.get_candidates(data[i], number=k, normalise=False)
        dist = dist + numpy.linalg.norm(data[i] - data[predict[k-1]])
    return dist / n

# %%
def evaluate(data, labels, n, k, t, leaf, steps, runs, avmra, avdia):
    global rc
    for r in range(runs):
        mra = numpy.empty(steps, dtype=float)
        dia = numpy.empty(steps, dtype=float)
        for i in range(steps):
            model = RPForest(leaf_size=leaf, no_trees=t)
            model.fit(data, normalise=False)
            miss = 0
            mra[i] = missrateav(n, k, model, data, labels, leaf)
            dia[i] = discrepancyav(n, k, model, data)
            model.clear()
            if t == 100:
                t = 10
            elif i == 0:
                t = t + 10
            else:
                t = t + 20
        for w in range(steps):
            avmra[w] = avmra[w] + mra[w]
            avdia[w] = avdia[w] + dia[w]
        rc = rc + 1
        if rc == 1:
            print(str(rc) + ' Execution Out of ' + str(run) + ' Completed Successfully!')
        else:
            print(str(rc) + ' Executions Out of ' + str(run) + ' Completed Successfully!')

# %%
from sklearn.ensemble import IsolationForest

# %%
def evaluate2(data, labels, n, k, t, leaf, steps, runs, avmra, avdia):
    global rc
    for r in range(runs):
        mra = numpy.empty(steps, dtype=float)
        dia = numpy.empty(steps, dtype=float)
        for i in range(steps):
            model = IsolationForest(leaf_size=leaf, no_trees=t)
            model.fit(data, normalise=False)
            miss = 0
            mra[i] = missrateav(n, k, model, data, labels, leaf)
            dia[i] = discrepancyav(n, k, model, data)
            model.clear()
            if t == 100:
                t = 10
            elif i == 0:
                t = t + 10
            else:
                t = t + 20
        for w in range(steps):
            avmra[w] = avmra[w] + mra[w]
            avdia[w] = avdia[w] + dia[w]
        rc = rc + 1
        if rc == 1:
            print(str(rc) + ' Execution Out of ' + str(run) + ' Completed Successfully!')
        else:
            print(str(rc) + ' Executions Out of ' + str(run) + ' Completed Successfully!')

# %%
def normalise(avdia, avdiatemp, steps):
    minim = numpy.min(avdiatemp)
    maxim = numpy.max(avdiatemp)
    for s in range(steps):
        avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
pip install scikit-surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      |████████████████████████████████| 771 kB 4.4 MB/s
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-surprise) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-surprise) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-surprise) (1.7.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp38-cp38-linux_x86_64.whl size=2626435 sha256=c693de371178b3f827dfeed61d959c37db394cf63ee1224c19f596b642e0167e
#   Stored in directory: /root/.cache/pip/wheels/af/db/86/2c18183a80ba05da35bf0fb7417aac5cddbd93bcb1b92fd3ea
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
import numpy
import csv
import threading
import pandas as pd

# %%
def read_lines():
    with open('Breastcancer.csv', 'r') as data2:
        labels = csv.reader(data2)
        for row in labels:
            yield [ float(i) for i in row ]

# %%
print('K Nearest Neighbour Search Using Random Projection Forests - Breast Cancer')
labels = list(read_lines())
n1 = data2.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data2, labels, n1, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data2, labels, n1, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data2, labels, n1, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data2, labels, n1, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
# Out:
# K Nearest Neighbour Search Using Random Projection Forests - Breast Cancer
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-256320b9eb64> in <module>
#       1 print('K Nearest Neighbour Search Using Random Projection Forests - Breast Cancer')
#       2 labels = list(read_lines())
# ----> 3 n1 = data2.shape[0]
#       4 k = 5
#       5 t = 10
#
# NameError: name 'data2' is not defined

# %%
import time

# %%
start = time.time()
print('KNN Search Using Random Projection Forests- Parkinsons')
data1 = numpy.loadtxt('park1.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('park1.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     Exception in thread self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# Thread-17:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     Exception in thread self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# Thread-18:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#       File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
#         self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# self.run()ValueError
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# : Does not understand character buffer dtype format string ('w')
# ValueError: Does not understand character buffer dtype format string ('w')
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# KNN Search Using Random Projection Forests- Parkinsons
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 194.503ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Isolation Forests- Parkinsons')
data1 = numpy.loadtxt('park1.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('park1.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Exception in thread Thread-19Thread-20:
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#         self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# self.run()    TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
#
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# KNN Search Using Isolation Forests- Parkinsons
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 157.786ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Random Projection Forests- Fetal heart Rate')
data1 = numpy.loadtxt('fhealthrate.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('fhealthrate.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# Thread-24:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Exception in thread     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# Thread-25Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#         self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# KNN Search Using Random Projection Forests- Fetal heart Rate
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 127.372ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Isolation Forests- Fetal Health Rate')
data1 = numpy.loadtxt('fhealthrate.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('fhealthrate.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread     Thread-28Exception in thread Thread-29self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# Exception in thread :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-30:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# KNN Search Using Isolation Forests- Fetal Health Rate
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 132.135ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Random Projection Forests- Breast Cancer')
data1 = numpy.loadtxt('Breastcancer.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('Breastcancer.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Exception in thread Thread-32:
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#         self.run()self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Thread-33
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#       File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# self.run()
# ValueError: Does not understand character buffer dtype format string ('w')
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# ValueError: Does not understand character buffer dtype format string ('w')
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# KNN Search Using Random Projection Forests- Breast Cancer
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 68.382ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Isolation Forests- Breast Cancer')
data1 = numpy.loadtxt('Breastcancer.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('Breastcancer.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Exception in thread Exception in thread Thread-37:
# Thread-36:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-35:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
#         self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#             self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
#     TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# KNN Search Using Isolation Forests- Breast Cancer
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 71.523ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Random Projection Forests- Dermatology')
data1 = numpy.loadtxt('d.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('d.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# KNN Search Using Random Projection Forests- Dermatology
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 53.204ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Isolation Forests- Dermatology')
data1 = numpy.loadtxt('d.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('d.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-43Exception in thread :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-45:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     Exception in thread self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# Thread-46self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# KNN Search Using Isolation Forests- Dermatology
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 45.305ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Random Projection Forests- Hungarian')
data1 = numpy.loadtxt('h.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('h.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
# Exception in thread   File "/usr/lib/python3.8/threading.py", line 870, in run
# Thread-56:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# Thread-57:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     self.run()    tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
#
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     ValueErrorself.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# : Does not understand character buffer dtype format string ('w')
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# KNN Search Using Random Projection Forests- Hungarian
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 78.188ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Isolation Forests- Hungarian')
data1 = numpy.loadtxt('h.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('h.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# Exception in thread Thread-60:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# KNN Search Using Isolation Forests- Hungarian
# Evaluating The Method...
# Exception in thread Thread-61:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# Exception in thread Thread-62:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 225.152ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Random Projection Forests- Diabetes')
data1 = numpy.loadtxt('d.csv', dtype=str,delimiter=' ')
labels = list(csv.reader(open('d.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# KNN Search Using Random Projection Forests- Diabetes
# Exception in thread Exception in thread Thread-103Thread-104:
# :
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)self.run()Exception in thread Thread-105:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
#
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-106:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 64, in fit
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 64, in fit
#     if X.shape[0] < 1 or X.shape[1] < 1:
# IndexError: tuple index out of range
#       File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 64, in fit
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#     if X.shape[0] < 1 or X.shape[1] < 1:
# IndexError: tuple index out of range
#     if X.shape[0] < 1 or X.shape[1] < 1:
# IndexError: tuple index out of range
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 64, in fit
#     if X.shape[0] < 1 or X.shape[1] < 1:
# IndexError: tuple index out of range
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 1502.994ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
start = time.time()
print('KNN Search Using Isolation Projection Forests- Diabetes')
data1 = numpy.loadtxt('d.csv', dtype=str,delimiter=' ')
labels = list(csv.reader(open('d.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
end = time.time()
print(f"Iteration: {j}\tTime taken: {(end-start)*10**3:.03f}ms")
# Out:
# KNN Search Using Isolation Projection Forests- Diabetes
# Exception in thread Thread-107:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-108:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     Exception in thread Thread-109:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# self.run()    self._target(*self._args, **self._kwargs)
#
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Thread-110TypeError    :
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# : self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# Iteration: 4	Time taken: 1478.823ms
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
print('KNN Search Using Random Projection Forests- Parkinsons')
data1 = numpy.loadtxt('park1.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('park1.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate2, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
# Out:
# KNN Search Using Random Projection Forests- Parkinsons
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-48:
#     Exception in thread Thread-49Traceback (most recent call last):
# self.run():
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-50  File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# :
#         self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
#         self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-23-7c83a285428e>", line 7, in evaluate2
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# TypeError: __init__() got an unexpected keyword argument 'leaf_size'
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
print('KNN Search Using Random Projection Forests- Slice Localisation')
data1 = numpy.loadtxt('fhealthrate.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('fhealthrate.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')
# Out:
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
# Thread-53    Exception in thread Thread-54:
# self.run()Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
# :
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError        : Does not understand character buffer dtype format string ('w')
# self._target(*self._args, **self._kwargs)    self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
#
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-21-57096b83a562>", line 8, in evaluate
#   File "/usr/local/lib/python3.8/dist-packages/rpforest/rpforest.py", line 79, in fit
#     tree.make_tree(self._X)
#   File "rpforest/rpforest_fast.pyx", line 236, in rpforest.rpforest_fast.Tree.make_tree
# ValueError: Does not understand character buffer dtype format string ('w')
# KNN Search Using Random Projection Forests- Slice Localisation
# Evaluating The Method...
# Operation Completed Successfully!
# Average Missing Rate For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# Average Discrepancy For Different Number of Trees in The Forest:
# [0. 0. 0. 0. 0.]
# All Operations Completed Successfully
# <ipython-input-24-0fc25b07f128>:5: RuntimeWarning: invalid value encountered in double_scalars
#   avdia[s] = (avdiatemp[s] - minim) / (maxim - minim)

# %%
print('KNN Search Using Random Projection Forests- Slice Localisation')
data1 = numpy.loadtxt('fhealthrate.csv', dtype=str,delimiter=',')
labels = list(csv.reader(open('fhealthrate.csv', 'r')))
n = data1.shape[0]
k = 5
t = 10
leaf = 20
steps = 5
run = 100
threads = 4
rc = 10
t1avmra = numpy.zeros(steps, dtype=float)
t1avdia = numpy.zeros(steps, dtype=float)
t2avmra = numpy.zeros(steps, dtype=float)
t2avdia = numpy.zeros(steps, dtype=float)
t3avmra = numpy.zeros(steps, dtype=float)
t3avdia = numpy.zeros(steps, dtype=float)
t4avmra = numpy.zeros(steps, dtype=float)
t4avdia = numpy.zeros(steps, dtype=float)
avmra = numpy.zeros(steps, dtype=float)
avdiatemp = numpy.zeros(steps, dtype=float)
avdia = numpy.zeros(steps, dtype=float)
print('Evaluating The Method...')
t1 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t1avmra, t1avdia))
t2 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t2avmra, t2avdia))
t3 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t3avmra, t3avdia))
t4 = threading.Thread(target=evaluate, args=(data1, labels, n, k, t, leaf, steps, int(run / threads), t4avmra, t4avdia))
t1.start()
t2.start()
t3.start()
t4.start()
t1.join()
t2.join()
t3.join()
t4.join()
for i in range(steps):
    avmra[i] = t1avmra[i] + t2avmra[i] + t3avmra[i] + t4avmra[i]
    avdiatemp[i] = t1avdia[i] + t2avdia[i] + t3avdia[i] + t4avdia[i]
for j in range(steps):
    avmra[j] = avmra[j] / rc
    avdiatemp[j] = avdiatemp[j] / rc
normalise(avdia, avdiatemp, steps)
print('Operation Completed Successfully!')
print('Average Missing Rate For Different Number of Trees in The Forest:')
print(avmra)
print('Average Discrepancy For Different Number of Trees in The Forest:')
print(avdiatem)
print('All Operations Completed Successfully')

# %%
import matplotlib.pyplot as plt
x1 = [10,20,40,60,80]
y1 = avmra
plt.plot(x1, y1, label = "Wdbc")
x2 = [10,20,40,60,80]
y2 = avmra
plt.plot(x2, y2, label = "fetal Heart Rate")
x3 = [10,20,40,60,80]
y3=avmra1
plt.plot(x3, y3, label = "Smartphone")
x3 = [10,20,40,60,80]
y3=avmra1
plt.plot(x3, y3, label = "Slice Localisation")
plt.xlabel('number of trees(K=5)')
plt.ylabel('avg missing rate')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x1 = [10,20,40,60,80]
y1 = avdiatem
plt.plot(x1, y1, label = "Wdbc")
x2 = [10,20,40,60,80]
y2 = avdiatem
plt.plot(x2, y2, label = "Parkinsons")
x3 = [10,20,40,60,80]
y3=avdia1
plt.plot(x3, y3, label = "Smartphone")
x3 = [10,20,40,60,80]
y3=avdia1
plt.plot(x3, y3, label = "Slice Localisation")
plt.xlabel('number of trees(K=5)')
plt.ylabel('avg distance error')
plt.legend()
plt.show()
